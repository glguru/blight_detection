# %%
import tensorflow as tf
from tqdm import tqdm
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda, Activation
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2lab, lab2rgb

from sklearn.model_selection import train_test_split

# %%
IMG_WIDHT = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 3

# %%
base_dir = "tomato/colour/"

sub_dirs = next(os.walk(base_dir))[1]
des_dir = "tomato/segmented_bw/"
sub_dirs
# Out:
# ['Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___healthy',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus']

# %%
#total number of images in all folders together

def get_files_list(base_dir):
    files = []
    for sub_dir in os.listdir(base_dir):
        ls = os.listdir(os.path.join(base_dir,sub_dir))
        for f in ls:
            files.append(os.path.join(base_dir,sub_dir,f))
    return files

# %%
raw_dir = 'tomato/colour/'
seg_dir = 'tomato/segmented_bw/'

# %%
raw_files_list = get_files_list(raw_dir)
seg_files_list = get_files_list(seg_dir)

# %%
X = np.zeros((len(raw_files_list), IMG_HEIGHT, IMG_WIDHT, IMG_CHANNELS), dtype=np.float32)
Y = np.zeros((len(seg_files_list), IMG_HEIGHT, IMG_WIDHT, 1), dtype=np.float32)

# %%
X.shape
# Out:
# (14707, 256, 256, 3)

# %%
Y.shape
# Out:
# (14707, 256, 256, 1)

# %%
def pre_process_imgs(image_bgr):

    image_bgr = cv2.resize(image_bgr, (IMG_HEIGHT, IMG_WIDHT))
    image_lab = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2LAB)

    # Separate LAB channels
    l_channel, a_channel, b_channel = cv2.split(image_lab)

    # Normalize LAB channels to the range [0, 1]
    l_channel_norm = l_channel / 255.0
    a_channel_norm = (a_channel + 128) / 255.0  # Shift a* component to [0, 255]
    b_channel_norm = (b_channel + 128) / 255.0  # Shift b* component to [0, 255]

    # Merge normalized LAB channels back into LAB image
    image_lab_norm = cv2.merge([l_channel_norm, a_channel_norm, b_channel_norm])
    return image_lab_norm

    # return image_lab

# %%
for n,id_ in tqdm(enumerate(raw_files_list),total=len(raw_files_list)):
    img = cv2.imread(id_, cv2.IMREAD_COLOR)
    img = pre_process_imgs(img)
    X[n] = img
# Out:
# 100%|██████████| 14707/14707 [00:30<00:00, 480.02it/s]

# %%
for n,id_ in tqdm(enumerate(seg_files_list),total=len(seg_files_list)):
    img = cv2.imread(id_, cv2.IMREAD_GRAYSCALE)
    img = np.expand_dims(cv2.resize(img, (IMG_HEIGHT, IMG_WIDHT)), axis=-1)
    img = img/255.0
    Y[n] = img
# Out:
# 100%|██████████| 14707/14707 [00:10<00:00, 1409.12it/s]

# %%
Y.shape
# Out:
# (12430, 256, 256, 1)

# %%
fig = plt.figure(figsize=(8, 8))
for i in range(1, 3*3 +1):
    img = X[i]
    l_channel, a_channel, b_channel = cv2.split(img)

    # Normalize LAB channels to the range [0, 1]
    l_channel_norm = l_channel * 255.0
    a_channel_norm = a_channel * 255 - 128 # Shift a* component to [0, 255]
    b_channel_norm = b_channel * 255 - 128  # Shift b* component to [0, 255]
    img = cv2.merge([l_channel_norm, a_channel_norm, b_channel_norm])
    fig.add_subplot(3, 3, i)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_LAB2BGR))
    # plt.imshow(img)

# %%
fig = plt.figure(figsize=(8, 8))
for i in range(1, 3*3 +1):
    img = Y[i]
    fig.add_subplot(3, 3, i)
    plt.imshow(img, cmap='gray')

# %%
x_train,_, y_train, _ = train_test_split(X,Y , random_state=42,test_size=0.4, shuffle=True)

fig = plt.figure(figsize=(8, 8))
for i in range(1, 3*3 +1):
    img = x_train[i]
    fig.add_subplot(3, 3, i)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_LAB2BGR))

plt.show()

fig = plt.figure(figsize=(8, 8))
for i in range(1, 3*3 +1):
    img = y_train[i]
    fig.add_subplot(3, 3, i)
    plt.imshow(img,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# d:\docs\amrita\MainProject\leaf_seg\u_net_res.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/docs/amrita/MainProject/leaf_seg/u_net_res.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> x_train,_, y_train, _ = train_test_split(X,Y , random_state=42,test_size=0.4, shuffle=True)
#       <a href='vscode-notebook-cell:/d%3A/docs/amrita/MainProject/leaf_seg/u_net_res.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> fig = plt.figure(figsize=(8, 8))
#       <a href='vscode-notebook-cell:/d%3A/docs/amrita/MainProject/leaf_seg/u_net_res.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> for i in range(1, 3*3 +1):
#
# File d:\docs\amrita\MainProject\leaf_seg\blight_env\lib\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File d:\docs\amrita\MainProject\leaf_seg\blight_env\lib\site-packages\sklearn\model_selection\_split.py:2672, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2668     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2670     train, test = next(cv.split(X=arrays[0], y=stratify))
# -> 2672 return list(
#    2673     chain.from_iterable(
#    2674         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2675     )
#    2676 )
#
# File d:\docs\amrita\MainProject\leaf_seg\blight_env\lib\site-packages\sklearn\model_selection\_split.py:2674, in <genexpr>(.0)
#    2668     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2670     train, test = next(cv.split(X=arrays[0], y=stratify))
#    2672 return list(
#    2673     chain.from_iterable(
# -> 2674         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2675     )
#    2676 )
#
# File d:\docs\amrita\MainProject\leaf_seg\blight_env\lib\site-packages\sklearn\utils\__init__.py:355, in _safe_indexing(X, indices, axis)
#     353     return _pandas_indexing(X, indices, indices_dtype, axis=axis)
#     354 elif hasattr(X, "shape"):
# --> 355     return _array_indexing(X, indices, indices_dtype, axis=axis)
#     356 else:
#     357     return _list_indexing(X, indices, indices_dtype)
#
# File d:\docs\amrita\MainProject\leaf_seg\blight_env\lib\site-packages\sklearn\utils\__init__.py:184, in _array_indexing(array, key, key_dtype, axis)
#     182 if isinstance(key, tuple):
#     183     key = list(key)
# --> 184 return array[key] if axis == 0 else array[:, key]
#
# MemoryError: Unable to allocate 6.46 GiB for an array with shape (8824, 256, 256, 3) and data type float32

# %%
# def res_conv_block(x, size, f_size):
#     c1 = Conv2D(size,(f_size, f_size), padding='same')(x)
#     c1 = Activation('relu')(c1)
#     c1 = Dropout(0.1*(size%16+1))(c1)
#     c1 = Conv2D(size,(f_size, f_size), padding='same')(c1)
#     # c1 = Activation('relu')(c1)
    
#     shortcut = Conv2D(size, kernel_size = (1,1), padding ='same')(x)

#     respath = tf.keras.layers.Add()([shortcut, c1])
#     respath = Activation('relu')(c1)

#     return respath

# %%
def res_conv_block(x, size, f_size):
    c1 = Conv2D(size,(f_size, f_size), padding='same',activation='relu')(x)
    # c1 = Activation('relu')(c1)
    c1 = Dropout(0.2)(c1)
    c1 = Conv2D(size,(f_size, f_size), padding='same', activation='relu')(c1)
    # c1 = Dropout(0.1*(size%16+1))(c1)
    # c1 = Activation('relu')(c1)
    
    shortcut = Conv2D(size, kernel_size = (1,1), padding ='same')(x)

    respath = tf.keras.layers.Add()([shortcut, c1])
    respath = Activation('relu')(c1)

    return respath

# %%
def build_Res_UNet(IMG_HEIGHT, IMG_WIDHT, IMG_CHANNELS):
    inputs = tf.keras.layers.Input((IMG_WIDHT, IMG_HEIGHT, IMG_CHANNELS))
    # s = tf.keras.layers.Lambda(lambda x:x/255)(inputs)
    #layer 1
    c1 = res_conv_block(x=inputs, size=16, f_size=3)
    p1 = MaxPooling2D((2,2))(c1)

    #layer 2
    c2 = res_conv_block(x=p1, size=32, f_size=3)
    p2 = MaxPooling2D((2,2))(c2)

    #layer 3
    c3 = res_conv_block(x=p2, size=64, f_size=3)
    p3 = MaxPooling2D((2,2))(c3)

    #layer 4
    c4 = res_conv_block(x=p3, size=128, f_size=3)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)
     
    #layer 5
    c5 = Conv2D(256, (3, 3), activation='relu',  padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu',  padding='same')(c5)

    #Expansive path 
    #layer 6
    u6 = UpSampling2D(size=(2,2), data_format="channels_last")(c5)
    # u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = res_conv_block(x=u6, size=128, f_size=3)
     
    #layer 7 
    u7 = UpSampling2D(size=(2,2), data_format="channels_last")(c6)
    # u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = res_conv_block(x=u7, size=64, f_size=3)
    
    #layer 8 
    u8 = UpSampling2D(size=(2,2), data_format="channels_last")(c7)
    # u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = res_conv_block(x=u8, size=32, f_size=3)
    
    #layer 9
    u9 = UpSampling2D(size=(2,2), data_format="channels_last")(c8)
    # u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = res_conv_block(x=u9, size=16, f_size=3)
     
    outputs = Conv2D(1, (1, 1), activation='sigmoid', padding = 'same')(c9)

    model = tf.keras.models.Model(inputs = inputs, outputs=outputs)

    return model

# %%
def dice_coef(y_true, y_pred):
    smooth = 1e-15
    y_true_f = tf.keras.layers.Flatten()(y_true)
    y_pred_f = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + 1.0)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true,y_pred)

# %%
model_act_later = build_Res_UNet(IMG_HEIGHT, IMG_WIDHT, IMG_CHANNELS)

model_act_later.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss=dice_loss, metrics=[dice_coef])

model_act_later.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 16)         448       ['input_1[0][0]']
#
#  dropout (Dropout)           (None, 256, 256, 16)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)         2320      ['dropout[0][0]']
#
#  activation (Activation)     (None, 256, 256, 16)         0         ['conv2d_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 16)         0         ['activation[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 32)         4640      ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 128, 128, 32)         0         ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 32)         9248      ['dropout_1[0][0]']
#
#  activation_1 (Activation)   (None, 128, 128, 32)         0         ['conv2d_4[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 32)           0         ['activation_1[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 64, 64, 64)           0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 64)           36928     ['dropout_2[0][0]']
#
#  activation_2 (Activation)   (None, 64, 64, 64)           0         ['conv2d_7[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 64)           0         ['activation_2[0][0]']
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 32, 32, 128)          0         ['conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 128)          147584    ['dropout_3[0][0]']
#
#  activation_3 (Activation)   (None, 32, 32, 128)          0         ['conv2d_10[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 128)          0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 256)          295168    ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 16, 16, 256)          0         ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 256)          590080    ['dropout_4[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 256)          0         ['conv2d_13[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 32, 32, 384)          0         ['up_sampling2d[0][0]',
#                                                                      'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 128)          442496    ['concatenate[0][0]']
#
#  dropout_5 (Dropout)         (None, 32, 32, 128)          0         ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 128)          147584    ['dropout_5[0][0]']
#
#  activation_4 (Activation)   (None, 32, 32, 128)          0         ['conv2d_15[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 128)          0         ['activation_4[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 192)          0         ['up_sampling2d_1[0][0]',
#  )                                                                   'activation_2[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 64, 64, 64)           110656    ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)         (None, 64, 64, 64)           0         ['conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 64, 64, 64)           36928     ['dropout_6[0][0]']
#
#  activation_5 (Activation)   (None, 64, 64, 64)           0         ['conv2d_18[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 64)         0         ['activation_5[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 96)         0         ['up_sampling2d_2[0][0]',
#  )                                                                   'activation_1[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 128, 128, 32)         27680     ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)         (None, 128, 128, 32)         0         ['conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 128, 128, 32)         9248      ['dropout_7[0][0]']
#
#  activation_6 (Activation)   (None, 128, 128, 32)         0         ['conv2d_21[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 32)         0         ['activation_6[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 48)         0         ['up_sampling2d_3[0][0]',
#  )                                                                   'activation[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 256, 256, 16)         6928      ['concatenate_3[0][0]']
#
#  dropout_8 (Dropout)         (None, 256, 256, 16)         0         ['conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 256, 256, 16)         2320      ['dropout_8[0][0]']
#
#  activation_7 (Activation)   (None, 256, 256, 16)         0         ['conv2d_24[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 256, 256, 1)          17        ['activation_7[0][0]']
#
# ==================================================================================================
# Total params: 1962625 (7.49 MB)
# Trainable params: 1962625 (7.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
#checkpoints

checkpointer = tf.keras.callbacks.ModelCheckpoint('tomato_lab_resu2.h5', verbose=1, save_best_only=True)

callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=3, monitor='val_loss'),
    tf.keras.callbacks.TensorBoard(log_dir='logs_lab_resu2'),
    checkpointer
]

results = model_act_later.fit(x_train,y_train, validation_split=0.2, batch_size=16, epochs=15, callbacks=callbacks,verbose=1)
# Out:
# Epoch 1/15
# 435/435 [==============================] - ETA: 0s - loss: 0.0995 - dice_coef: 0.9005
# Epoch 1: val_loss improved from inf to 0.05620, saving model to tomato_lab_resu2.h5
# c:\Users\I741666\Desktop\blight detection\leaf_seg\blight_env\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 435/435 [==============================] - 2668s 6s/step - loss: 0.0995 - dice_coef: 0.9005 - val_loss: 0.0562 - val_dice_coef: 0.9439
# Epoch 2/15
# 435/435 [==============================] - ETA: 0s - loss: 0.0565 - dice_coef: 0.9435
# Epoch 2: val_loss improved from 0.05620 to 0.05604, saving model to tomato_lab_resu2.h5
# 435/435 [==============================] - 2642s 6s/step - loss: 0.0565 - dice_coef: 0.9435 - val_loss: 0.0560 - val_dice_coef: 0.9440
# Epoch 3/15
# 435/435 [==============================] - ETA: 0s - loss: 0.0550 - dice_coef: 0.9450
# Epoch 3: val_loss improved from 0.05604 to 0.05341, saving model to tomato_lab_resu2.h5
# 435/435 [==============================] - 2616s 6s/step - loss: 0.0550 - dice_coef: 0.9450 - val_loss: 0.0534 - val_dice_coef: 0.9466
# Epoch 4/15
# 435/435 [==============================] - ETA: 0s - loss: 0.0542 - dice_coef: 0.9458
# Epoch 4: val_loss improved from 0.05341 to 0.05139, saving model to tomato_lab_resu2.h5
# 435/435 [==============================] - 4502s 10s/step - loss: 0.0542 - dice_coef: 0.9458 - val_loss: 0.0514 - val_dice_coef: 0.9487
# Epoch 5/15
# 195/435 [============>.................] - ETA: 21:11:20 - loss: 0.0549 - dice_coef: 0.9451

# %%
#--------------------------------------------------------------------------------------------------------

# %%
model = build_Res_UNet(IMG_HEIGHT, IMG_WIDHT, IMG_CHANNELS)

model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss=dice_loss, metrics=[dice_coef])

model.summary()

# %%
#checkpoints

checkpointer = tf.keras.callbacks.ModelCheckpoint('tomato_lab_resu1.h5', verbose=1, save_best_only=True)

callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=3, monitor='val_loss'),
    tf.keras.callbacks.TensorBoard(log_dir='logs_lab_resu'),
    checkpointer
]

# %%
results = model.fit(x_train,y_train, validation_split=0.2, batch_size=16, epochs=15, callbacks=callbacks,verbose=1)

# %%
from tensorflow.keras.models import Model
def get_intermediate_outputs(model, layer_names, input_data):
    intermediate_models = [Model(inputs=model.input, outputs=model.get_layer(layer_name).output) for layer_name in layer_names]
    intermediate_outputs = [intermediate_model.predict(input_data) for intermediate_model in intermediate_models]
    return intermediate_outputs

# %%
op = u_net_pv_tomato_test1.get_layer('max_pooling2d_8').output

# %%
x_train[1].shape

# %%
model = u_net_pv_tomato_test1

model.summary()

# %%
example_input =  x_train[1].reshape((1,256,256,3))


# Specify the layer names for which you want to visualize the outputs
layer_names_to_visualize = ['input_3','lambda_2','conv2d_38','conv2d_39','max_pooling2d_8', 'max_pooling2d_9']

# Get intermediate outputs
intermediate_outputs = get_intermediate_outputs(model, layer_names_to_visualize, example_input)

# Visualize intermediate outputs
for i, layer_name in enumerate(layer_names_to_visualize):
    plt.figure(figsize=(8, 8))
    imshow(intermediate_outputs[i][0, :, :, 0], cmap='viridis')  # Adjust indices as needed
    plt.title(f'Layer: {layer_name} - Output')
    plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load your original image (replace 'original_image.jpg' with your image file)
original_image = imread('tomato/colour/Tomato___Bacterial_spot/00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_Bact.Sp 3110.JPG')
imshow(original_image)
original_image = resize(original_image, (IMG_HEIGHT, IMG_WIDHT), mode='constant', preserve_range=True)

# Load your binary mask (replace 'binary_mask.jpg' with your binary mask file)
binary_mask = cv2.imread('tomato/segmented_bw/Tomato___Bacterial_spot/00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_Bact.Sp 3110_final_masked.jpg', cv2.IMREAD_GRAYSCALE)

# Ensure that the binary mask is binary (contains only 0 and 255 values)
binary_mask = (binary_mask > 0).astype(np.uint8)

# Apply the binary mask to the original image
segmented_image = cv2.bitwise_and(original_image, original_image, mask=binary_mask)

# Visualize the original image, binary mask, and segmented image
plt.subplot(1, 3, 1)
plt.imshow(original_image)
plt.title('Original Image')

plt.subplot(1, 3, 2)
plt.imshow(binary_mask, cmap='gray')
plt.title('Binary Mask')

plt.subplot(1, 3, 3)
plt.imshow(segmented_image)
plt.title('Segmented Image')

# %%
plt.imshow(X[1])

# %%
res = model.predict(X[1].reshape(1,256,256,3))

# %%
res.shape

# %%
model_act_later = build_Res_UNet(IMG_HEIGHT, IMG_WIDHT, IMG_CHANNELS)

model_act_later.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss=dice_loss, metrics=[dice_coef])

model_act_later.summary()

# %%
#checkpoints

checkpointer = tf.keras.callbacks.ModelCheckpoint('tomato_lab_resu2.h5', verbose=1, save_best_only=True)

callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=3, monitor='val_loss'),
    tf.keras.callbacks.TensorBoard(log_dir='logs_lab_resu2'),
    checkpointer
]

results = model_act_later.fit(x_train,y_train, validation_split=0.2, batch_size=16, epochs=15, callbacks=callbacks,verbose=1)
